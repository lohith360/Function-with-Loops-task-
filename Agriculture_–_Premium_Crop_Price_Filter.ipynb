# %%
def filter_premium(prices):
    return [p for p in prices if p > 2000]

prices = [int(x) for x in input("Enter crop prices separated by space: ").split()]
print(f"Premium Crops: {filter_premium(prices)}")
