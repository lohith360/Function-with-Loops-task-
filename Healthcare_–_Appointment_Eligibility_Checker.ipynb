# %%
def check_eligibility(age):
    return "Eligible" if age >= 18 else "Not Eligible"

age = int(input("Enter patient age: "))
print(f"Patient Age: {age}\nEligibility Status: {check_eligibility(age)}")
