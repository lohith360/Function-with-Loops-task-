# %%
def calculate_bill(units):
    bill = 0
    if units > 200:
        bill += (units - 200) * 7
        units = 200
    if units > 100:
        bill += (units - 100) * 5
        units = 100
    bill += units * 3

    if bill < 500: usage = "Low Usage"
    elif bill <= 1500: usage = "Moderate Usage"
    else: usage = "High Usage"

    return bill, usage

units = int(input("Enter units consumed: "))
b, u = calculate_bill(units)
print(f"Total Bill: ₹{b}\nUsage Class: {u}")
