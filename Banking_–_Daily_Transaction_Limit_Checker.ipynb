# %%
def check_transaction(amount):
    return "Approved" if amount <= 50000 else "Rejected"

amount = int(input("Enter transaction amount: "))
print(f"Transaction Amount: {amount}\nTransaction Status: {check_transaction(amount)}")
