# %%
def check_duplicates(usernames):
    return "Yes" if len(usernames) != len(set(usernames)) else "No"

users = input("Enter usernames separated by space: ").split()
print(f"Duplicate Accounts Found: {check_duplicates(users)}")
