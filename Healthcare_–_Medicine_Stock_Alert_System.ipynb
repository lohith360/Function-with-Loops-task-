# %%
def check_stock(stock):
    return "Low Stock Alert" if stock < 10 else "Stock Sufficient"

stock = int(input("Enter medicine stock level: "))
print(f"Medicine Stock: {stock}\nStatus: {check_stock(stock)}")
