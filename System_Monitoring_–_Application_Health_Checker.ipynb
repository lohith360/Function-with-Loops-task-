# %%
def check_health(errors):
    if errors == 0: return "Healthy"
    return "Minor Issues" if errors <= 5 else "Critical Issues"

errors = int(input("Enter error count: "))
print(f"Error Count: {errors}\nSystem Status: {check_health(errors)}")
